# %% [markdown]
# # ***Database Design***

# %%
# Import Libraries:
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
# Create connection string using credentials
# connection = "dialect+driver://username:password@host:port/database"

connection = "mysql+pymysql://root:root@localhost/project3"

# %%
# Check if database exists:

engine = create_engine(connection)

if database_exists(connection) == False: engine
else: print('The database already exists.')
# Out:
# The database already exists.

# %%
# Load csv files from part I:

bdf = pd.read_csv('C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Project-3\\Data\\title_basics.csv.gz')

bdf.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult   startYear  endYear  \
# 0                             Kate & Leopold        0  2001-01-01      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0  2020-01-01      NaN
# 2                 The Other Side of the Wind        0  2018-01-01      NaN
# 3                              November 1828        0  2001-01-01      NaN
# 4                          The Naked Monster        0  2005-01-01      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
bdf.drop(columns= {'originalTitle', 'endYear', 'titleType', 'isAdult'}, inplace = True)

# %% [markdown]
# Convert the single string of genres from title basics into 2 new tables.
# title_genres: with the columns:
#
#     tconst
#     genre_id

# %%
# Convert start Year to datetime:

bdf['startYear'] = pd.to_datetime(bdf['startYear'])
bdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140788 entries, 0 to 140787
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          140788 non-null  object
#  1   primaryTitle    140788 non-null  object
#  2   startYear       140788 non-null  datetime64[ns]
#  3   runtimeMinutes  140788 non-null  int64
#  4   genres          140788 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 5.4+ MB

# %%
# bdf['startYear'].dt.year

# %%
# Column with list of genres:

bdf['genres_split'] = bdf['genres'].str.split(',')
bdf
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0079644                                      November 1828
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 140783  tt9916170                                      The Rehearsal
# 140784  tt9916190                                          Safeguard
# 140785  tt9916270                           Il talento del calabrone
# 140786  tt9916362                                              Coven
# 140787  tt9916538                                Kuambil Lagi Hatiku
#
#         startYear  runtimeMinutes                     genres  \
# 0      2001-01-01             118     Comedy,Fantasy,Romance
# 1      2020-01-01              70                      Drama
# 2      2018-01-01             122                      Drama
# 3      2001-01-01             140                  Drama,War
# 4      2005-01-01             100       Comedy,Horror,Sci-Fi
# ...           ...             ...                        ...
# 140783 2019-01-01              51                      Drama
# 140784 2020-01-01              90  Action,Adventure,Thriller
# 140785 2020-01-01              84                   Thriller
# 140786 2020-01-01              92              Drama,History
# 140787 2019-01-01             123                      Drama
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                        [Drama, War]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 140783                        [Drama]
# 140784  [Action, Adventure, Thriller]
# 140785                     [Thriller]
# 140786               [Drama, History]
# 140787                        [Drama]
#
# [140788 rows x 6 columns]

# %%
# Use of .explode() to separate the list of genres into new rows: 

exploded_genres = bdf.explode('genres_split')
exploded_genres
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# ...           ...                                                ...
# 140784  tt9916190                                          Safeguard
# 140785  tt9916270                           Il talento del calabrone
# 140786  tt9916362                                              Coven
# 140786  tt9916362                                              Coven
# 140787  tt9916538                                Kuambil Lagi Hatiku
#
#         startYear  runtimeMinutes                     genres genres_split
# 0      2001-01-01             118     Comedy,Fantasy,Romance       Comedy
# 0      2001-01-01             118     Comedy,Fantasy,Romance      Fantasy
# 0      2001-01-01             118     Comedy,Fantasy,Romance      Romance
# 1      2020-01-01              70                      Drama        Drama
# 2      2018-01-01             122                      Drama        Drama
# ...           ...             ...                        ...          ...
# 140784 2020-01-01              90  Action,Adventure,Thriller     Thriller
# 140785 2020-01-01              84                   Thriller     Thriller
# 140786 2020-01-01              92              Drama,History        Drama
# 140786 2020-01-01              92              Drama,History      History
# 140787 2019-01-01             123                      Drama        Drama
#
# [244131 rows x 6 columns]

# %%
# Get the string column converted to a list of strings in each row:

xgenres = bdf['genres'].str.split(",")

# Explode the series  using .epxlode() and take the unique () entries only.

unique_genres = xgenres.explode().unique()

unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'War', 'Horror', 'Sci-Fi',
#        'Music', 'Thriller', 'Mystery', 'Adventure', 'Musical', 'Action',
#        'Crime', 'Animation', 'Family', 'History', 'Biography', 'Sport',
#        'Western', 'Adult', 'Short', 'Reality-TV', 'News', 'Talk-Show',
#        'Game-Show'], dtype=object)

# %%
# Use of .unique() to get the unique genres from the genres_split column:

unique_genres = sorted(exploded_genres['genres_split'].unique()) 

unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
# tconst and split genres as new df:

title_genres = exploded_genres[['tconst', 'genres_split']].copy()

title_genres
# Out:
#            tconst genres_split
# 0       tt0035423       Comedy
# 0       tt0035423      Fantasy
# 0       tt0035423      Romance
# 1       tt0062336        Drama
# 2       tt0069049        Drama
# ...           ...          ...
# 140784  tt9916190     Thriller
# 140785  tt9916270     Thriller
# 140786  tt9916362        Drama
# 140786  tt9916362      History
# 140787  tt9916538        Drama
#
# [244131 rows x 2 columns]

# %%
# Numeric IDs for the varous genres via mapper dictionary:

genreints = range(len(unique_genres))
gmap = dict(zip(unique_genres, genreints))
gmap
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# Make a dictionary with list of unique genres as the key
# New integre ID as the values:

genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# New integer genre_id and drop string genres:

title_genres['genre_id'] = title_genres['genres_split'].map(gmap)
title_genres = title_genres.drop(columns='genres_split')

title_genres
# Out:
#            tconst  genre_id
# 0       tt0035423         5
# 0       tt0035423         9
# 0       tt0035423        18
# 1       tt0062336         7
# 2       tt0069049         7
# ...           ...       ...
# 140784  tt9916190        23
# 140785  tt9916270        23
# 140786  tt9916362         7
# 140786  tt9916362        11
# 140787  tt9916538         7
#
# [244131 rows x 2 columns]

# %%
# Manually make DataFrame with columns from .key and .values:

genre_search = pd.DataFrame({'genre_name' : genre_id_map.keys(), 'genre_id': genre_id_map.values()})

genre_search.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
# Drop genres and genres_split:

bdf.drop(columns = {'genres', 'genres_split'}, inplace = True)

# %%
bdf.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold 2001-01-01
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi... 2020-01-01
# 2  tt0069049                         The Other Side of the Wind 2018-01-01
# 3  tt0079644                                      November 1828 2001-01-01
# 4  tt0088751                                  The Naked Monster 2005-01-01
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             140
# 4             100

# %%
bdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140788 entries, 0 to 140787
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          140788 non-null  object
#  1   primaryTitle    140788 non-null  object
#  2   startYear       140788 non-null  datetime64[ns]
#  3   runtimeMinutes  140788 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 4.3+ MB

# %%
bdf.dtypes
# Out:
# tconst                    object
# primaryTitle              object
# startYear         datetime64[ns]
# runtimeMinutes             int64
# dtype: object

# %%
bdf.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold 2001-01-01
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi... 2020-01-01
# 2  tt0069049                         The Other Side of the Wind 2018-01-01
# 3  tt0079644                                      November 1828 2001-01-01
# 4  tt0088751                                  The Naked Monster 2005-01-01
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             140
# 4             100

# %%
# Saving table to the MySQL table:

from sqlalchemy.types import *

# Calculate max string lengths for object columns:
key_len = bdf['tconst'].fillna('').map(len).max()
title_len = bdf['primaryTitle'].fillna('').map(len).max()

# Create a schema dicitonary using Sqlalchamey data types objects:

schema = {"tconst": String(key_len+1),
               "primaryTitle": Text(title_len+1),
               'startYear': Float(),
               'runtimeMinutes': Integer()}

# %%
# Save to sql with dtype and idex = Fasle:

bdf.to_sql('title_basics', engine, dtype = schema, if_exists = 'replace', index = False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1799                     self.dialect.do_executemany(
# -> 1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     178                 self.max_stmt_length,
# --> 179                 self._get_db().encoding,
#     180             )
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     205             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 206                 rows += self.execute(sql + postfix)
#     207                 sql = bytearray(prefix)
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (1265, "Data truncated for column 'startYear' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26348\3632383745.py in <module>
#       1 # Save to sql with dtype and idex = Fasle:
#       2
# ----> 3 bdf.to_sql('title_basics', engine, dtype = schema, if_exists = 'replace', index = False)
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1304             )
#    1305         else:
# -> 1306             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1307
#    1308     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1506             elem,
#    1507             extracted_params,
# -> 1508             cache_hit=cache_hit,
#    1509         )
#    1510         if has_events:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1861         except BaseException as e:
#    1862             self._handle_dbapi_exception(
# -> 1863                 e, statement, parameters, cursor, context
#    1864             )
#    1865
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2042             elif should_wrap:
#    2043                 util.raise_(
# -> 2044                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045                 )
#    2046             else:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
#    1799                     self.dialect.do_executemany(
# -> 1800                         cursor, statement, parameters, context
#    1801                     )
#    1802             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     191
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#     195             context._rowcount = rowcount
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     177                 args,
#     178                 self.max_stmt_length,
# --> 179                 self._get_db().encoding,
#     180             )
#     181
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     204                 v = v.encode(encoding, "surrogateescape")
#     205             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 206                 rows += self.execute(sql + postfix)
#     207                 sql = bytearray(prefix)
#     208             else:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1265, "Data truncated for column 'startYear' at row 1")
# [SQL: INSERT INTO title_basics (tconst, `primaryTitle`, `startYear`, `runtimeMinutes`) VALUES (%(tconst)s, %(primaryTitle)s, %(startYear)s, %(runtimeMinutes)s)]
# [parameters: ({'tconst': 'tt0035423', 'primaryTitle': 'Kate & Leopold', 'startYear': datetime.datetime(2001, 1, 1, 0, 0), 'runtimeMinutes': 118}, {'tconst': 'tt0062336', 'primaryTitle': 'The Tango of the Widower and Its Distorting Mirror', 'startYear': datetime.datetime(2020, 1, 1, 0, 0), 'runtimeMinutes': 70}, {'tconst': 'tt0069049', 'primaryTitle': 'The Other Side of the Wind', 'startYear': datetime.datetime(2018, 1, 1, 0, 0), 'runtimeMinutes': 122}, {'tconst': 'tt0079644', 'primaryTitle': 'November 1828', 'startYear': datetime.datetime(2001, 1, 1, 0, 0), 'runtimeMinutes': 140}, {'tconst': 'tt0088751', 'primaryTitle': 'The Naked Monster', 'startYear': datetime.datetime(2005, 1, 1, 0, 0), 'runtimeMinutes': 100}, {'tconst': 'tt0089067', 'primaryTitle': 'El día de los albañiles 2', 'startYear': datetime.datetime(2001, 1, 1, 0, 0), 'runtimeMinutes': 90}, {'tconst': 'tt0092960', 'primaryTitle': 'En tres y dos', 'startYear': datetime.datetime(2004, 1, 1, 0, 0), 'runtimeMinutes': 102}, {'tconst': 'tt0093119', 'primaryTitle': 'Grizzly II: Revenge', 'startYear': datetime.datetime(2020, 1, 1, 0, 0), 'runtimeMinutes': 74}  ... displaying 10 of 140788 total bound parameter sets ...  {'tconst': 'tt9916362', 'primaryTitle': 'Coven', 'startYear': datetime.datetime(2020, 1, 1, 0, 0), 'runtimeMinutes': 92}, {'tconst': 'tt9916538', 'primaryTitle': 'Kuambil Lagi Hatiku', 'startYear': datetime.datetime(2019, 1, 1, 0, 0), 'runtimeMinutes': 123})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %%
# Set desired column as primary key:

engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (tconst);')

# %%
# Import other csvs files:

ratings = pd.read_csv('C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Project-3\\Data\\ratings.csv.gz')

ratings.head()

# %%
# Add  DataFrames as tables to Database:

ratings.to_sql('title_ratings',engine, if_exists='replace')

# %%
title_genres.to_sql('title_genres',engine, if_exists='replace')

# %%
genre_search.to_sql('genres',engine, if_exists='replace')

# %%
# Import final tmdb results:

tmdb = pd.read_csv('C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Project-3\\Data\\finalyears.csv.gz')

tmdb.head()

# %%
# Reduce the DataFrame down to 4 columns:

tmdb = tmdb[['imdb_id', 'revenue', 'budget', 'certification']]
tmdb.head()

# %%
# Add tmdb table to Database:

tmdb.to_sql('tmdb',engine, if_exists='replace')

# %% [markdown]
# ## SQL Queries

# %%
q = """SELECT *
FROM title_basics
LIMIT 5;"""
pd.read_sql(q,engine)

# %%
q = """SELECT *
FROM title_ratings
LIMIT 5;"""
pd.read_sql(q,engine)

# %%
q = """SELECT *
FROM title_genres
LIMIT 5;"""
pd.read_sql(q,engine)

# %%
q = """SELECT *
FROM genres
LIMIT 5;"""
pd.read_sql(q,engine)

# %%
q = """SELECT *
FROM tmdb
LIMIT 5;"""
pd.read_sql(q,engine)

# %%
q = """SHOW TABLES"""
pd.read_sql(q,engine)
